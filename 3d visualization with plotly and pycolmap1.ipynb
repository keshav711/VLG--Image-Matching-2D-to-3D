# %% [markdown]
# #Importing libraries

# %%
# !virtualenv myenv -q

# %%
#Pandas
try:
    import pandas as pd 
    print("pandas version-",pd.__version__)
except:
    # !pip install pandas -q
    import pandas as pd 
    print("pandas version-",pd.__version__)
#numpy
try:
    import numpy as np
    print("numpy version-",np.__version__)
except:
    # !pip install numpy -q
    import numpy as np
    print("numpy version-",np.__version__)
#os,time,path
import os
import time
from pathlib import Path
#matplotlib 
try:
    import matplotlib as plt
    print("matplotlib version-",plt.__version__)
except:
    # !pip install matplotlib -q
    import matplotlib as plt
    print("matplotlib version-",plt.__version__)
#plotly
try:
    import plotly
    import plotly.express as px
    import plotly.graph_objects as  go
    print("plotly version-",plotly.__version__)
except:
    # !pip install plotly -q
    import plotly
    import plotly.express as px
    import plotly.graph_objects as  go
    print("plotly version-",plotly.__version__)

#opencv   
try:
    import cv2
    print("opencv version-",cv2.__version__)
except:
    # !pip install opencv-python -q
    import cv2
    print("opencv version",cv2.__version__)
#scikit-image
try:
    import skimage
    print("scikit image version",skimage.__version__) 
except:
    # !pip install scikit-image -q
    import skimage
    print("scikit image version",skimage.__version__)
#pycolmap    
try:
    import pycolmap
    print("pycolmap version",pycolmap.__version__)
except:
    # !pip install pycolmap -q
    import pycolmap
    print("pycolmap version",pycolmap.__version__)
#mediapy
try:
    import mediapy as media
    print("mediapy version", media.__version__)
except: 
    # !pip install mediapy -q
    import mediapy as media
    print("mediapy version", media.__version__)
#glob
from glob import glob

# %%
current_path = os.getcwd()
current_path

# %%
# %cd {current_path}
#importing hierarchical
# !rm -rf {current_path}/Hierarchical-Localization
# !git clone --quiet --recursive https://github.com/cvg/Hierarchical-Localization/
# %cd {current_path}/Hierarchical-Localization
# !pip install -e . -q

from hloc import extract_features, match_features, reconstruction, visualization, pairs_from_exhaustive
from hloc.visualization import plot_images, read_image
from hloc.utils import viz_3d

# %cd /{current_path}

# %%
train_labels = pd.read_csv("/kaggle/input/image-matching-challenge-2023/train/train_labels.csv")

# %%
train_labels.head(5)

# %%
train_labels.tail()

# %%
train_labels.shape

# %%
train_labels.describe()

# %%
dataset_counts = train_labels.dataset.value_counts()
dataset_names=  dataset_counts.index
'''Calculates the count of each unique value in the "dataset" column of the DataFrame 
or Series object train_labels and assigns the result to the variable dataset_counts.'''
#making an pie chart with plotly express
fig = px.pie(values=dataset_counts.values, names=dataset_names)
fig.update_layout(
    title={
        'text': "Pie distribution of dataset images"
    },
    legend_title_text='Dataset names:'
)
fig.show()

# %%
scene_counts = train_labels.scene.value_counts()
scene_names=  scene_counts.index
'''Calculates the count of each unique value in the "scene" column of the DataFrame 
or Series object train_labels and assigns the result to the variable scene_counts'''
#making an pie chart with plotly express
fig = px.pie(values=scene_counts.values, names=scene_names)
fig.update_layout(
    title={
        'text': "Pie distribution of scene images"
    },
    legend_title_text='scene names:'
)
fig.show()

# %%
#sunburst of scene  and dataset
fig = px.sunburst(train_labels_df, path=['dataset', 'scene'])
fig.update_layout(
    title={
        'text': "Dataset and scene relation",
    }
)

fig.show()

# %%
dataset = 'heritage'
scene = 'dioscuri'
src = f'/kaggle/input/image-matching-challenge-2023/train/{dataset}/{scene}'

# %%
limit = 16
images = [cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB) for im in glob(f'{src}/images/*')[:limit]]
media.show_images(images, height=100, columns=4)

# %%
rec_gt = pycolmap.Reconstruction(f'{src}/sfm')

fig = viz_3d.init_figure()
# viz_3d.plot_cameras(fig, rec_gt, color='rgba(50,255,50, 0.5)', name="Ground Truth", size=10)
viz_3d.plot_reconstruction(fig, rec_gt, cameras = False, color='rgba(227,168,30,0.5)', name="Ground Truth", cs=5)
fig.show()

# %%
scene = 'wall'
src = f'/kaggle/input/image-matching-challenge-2023/train/{dataset}/{scene}'
limit = 16
images = [cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB) for im in glob(f'{src}/images/*')[:limit]]
media.show_images(images, height=100, columns=4)

# %% [markdown]
# <p style="font-family: consolas; font-size: 16px;">❔ Let's plot a 3D map of the scene.</p>

# %%
rec_gt = pycolmap.Reconstruction(f'{src}/sfm')
fig = viz_3d.init_figure()
# viz_3d.plot_cameras(fig, rec_gt, color='rgba(50,255,50, 0.5)', name="Ground Truth", size=10)
viz_3d.plot_reconstruction(fig, rec_gt, cameras = False, color='rgba(107,104,90,0.5)', name="Ground Truth", cs=5)
fig.show()

# %%
scene = 'cyprus'
src = f'/kaggle/input/image-matching-challenge-2023/train/{dataset}/{scene}'
limit = 16
images = [cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB) for im in glob(f'{src}/images/*')[:limit]]
media.show_images(images, height=100, columns=4)

# %%
rec_gt = pycolmap.Reconstruction(f'{src}/sfm')

fig = viz_3d.init_figure()
# viz_3d.plot_cameras(fig, rec_gt, color='rgba(50,255,50, 0.5)', name="Ground Truth", size=10)
viz_3d.plot_reconstruction(fig, rec_gt, cameras = False, color='rgba(245,212,66,0.5)', name="Ground Truth", cs=5)
fig.show()

# %%
dataset = 'haiper'

# %%
scene = 'fountain'
src = f'/kaggle/input/image-matching-challenge-2023/train/{dataset}/{scene}'

# %%
limit = 16
images = [cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB) for im in glob(f'{src}/images/*')[:limit]]
media.show_images(images, height=100, columns=4)

# %%
rec_gt = pycolmap.Reconstruction(f'{src}/sfm')

fig = viz_3d.init_figure()
# viz_3d.plot_cameras(fig, rec_gt, color='rgba(50,255,50, 0.5)', name="Ground Truth", size=10)
viz_3d.plot_reconstruction(fig, rec_gt, cameras = False, color='rgba(224,220,211,0.5)', name="Ground Truth", cs=5)
fig.show()

# %%
scene = 'chairs'
src = f'/kaggle/input/image-matching-challenge-2023/train/{dataset}/{scene}'

limit = 16
images = [cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB) for im in glob(f'{src}/images/*')[:limit]]
media.show_images(images, height=100, columns=4)

# %%
rec_gt = pycolmap.Reconstruction(f'{src}/sfm')

fig = viz_3d.init_figure()
# viz_3d.plot_cameras(fig, rec_gt, color='rgba(50,255,50, 0.5)', name="Ground Truth", size=10)
viz_3d.plot_reconstruction(fig, rec_gt, cameras = False, color='rgba(103,143,114,0.5)', name="Ground Truth", cs=5)
fig.show()

# %%
scene = 'bike'
src = f'/kaggle/input/image-matching-challenge-2023/train/{dataset}/{scene}'

limit = 16
images = [cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB) for im in glob(f'{src}/images/*')[:limit]]
media.show_images(images, height=100, columns=4)

# %%
rec_gt = pycolmap.Reconstruction(f'{src}/sfm')

fig = viz_3d.init_figure()
# viz_3d.plot_cameras(fig, rec_gt, color='rgba(50,255,50, 0.5)', name="Ground Truth", size=10)
viz_3d.plot_reconstruction(fig, rec_gt, cameras = False, color='rgba(156,153,140,0.5)', name="Ground Truth", cs=5)
fig.show()

# %%
dataset = 'urban'

# %%
scene = 'kyiv-puppet-theater'
src = f'/kaggle/input/image-matching-challenge-2023/train/{dataset}/{scene}'

limit = 16
images = [cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB) for im in glob(f'{src}/images/*')[:limit]]
media.show_images(images, height=100, columns=4)

# %%
rec_gt = pycolmap.Reconstruction(f'{src}/sfm')

fig = viz_3d.init_figure()
# viz_3d.plot_cameras(fig, rec_gt, color='rgba(50,255,50, 0.5)', name="Ground Truth", size=10)
viz_3d.plot_reconstruction(fig, rec_gt, cameras = False, color='rgba(201,56,110,0.5)', name="Ground Truth", cs=5)
fig.show()
